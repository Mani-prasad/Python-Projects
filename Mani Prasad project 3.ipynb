# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
cus=pd.read_csv('Customer.csv',parse_dates=["DOB"])

# %%
prod=pd.read_csv('prod_cat_info.csv')

# %%
tran=pd.read_csv('Transactions.csv',parse_dates=["tran_date"])

# %%
cus
# Out:
#       customer_Id        DOB Gender  city_code
# 0          268408 1970-02-01      M        4.0
# 1          269696 1970-07-01      F        8.0
# 2          268159 1970-08-01      F        8.0
# 3          270181 1970-10-01      F        2.0
# 4          268073 1970-11-01      M        1.0
# ...           ...        ...    ...        ...
# 5642       274474 1992-12-19      M        2.0
# 5643       267666 1992-12-24      M        6.0
# 5644       270476 1992-12-25      F        3.0
# 5645       269626 1992-12-27      F        5.0
# 5646       274308 1992-12-29      F        5.0
#
# [5647 rows x 4 columns]

# %%
cus.head()
# Out:
#    customer_Id        DOB Gender  city_code
# 0       268408 1970-02-01      M        4.0
# 1       269696 1970-07-01      F        8.0
# 2       268159 1970-08-01      F        8.0
# 3       270181 1970-10-01      F        2.0
# 4       268073 1970-11-01      M        1.0

# %%
cus.shape
# Out:
# (5647, 4)

# %%
prod
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
prod.head()
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %%
prod.shape
# Out:
# (23, 4)

# %%
tran
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
tran.shape
# Out:
# (23053, 10)

# %%
1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to
keep all customers who have done transactions with us and select the join type accordingly.

# %%
tran=tran.rename(columns={'cust_id':'customer_id'})

# %%
cus=cus.rename(columns={'customer_Id':'customer_id'})

# %%
prod=prod.rename(columns={'prod_sub_cat_code':'prod_subcat_code'})

# %%
prod
# Out:
#     prod_cat_code          prod_cat  prod_subcat_code          prod_subcat
# 0               1          Clothing                 4                 Mens
# 1               1          Clothing                 1                Women
# 2               1          Clothing                 3                 Kids
# 3               2          Footwear                 1                 Mens
# 4               2          Footwear                 3                Women
# 5               2          Footwear                 4                 Kids
# 6               3       Electronics                 4              Mobiles
# 7               3       Electronics                 5            Computers
# 8               3       Electronics                 8  Personal Appliances
# 9               3       Electronics                 9              Cameras
# 10              3       Electronics                10      Audio and video
# ...

# %%
cus
# Out:
#       customer_id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
mercusid=pd.merge(cus,tran,how='inner',on='customer_id')

# %%
Customer_Final=pd.merge(mercusid,prod,how='inner',on='prod_subcat_code')

# %%
Customer_Final
# Out:
#        customer_id        DOB Gender  city_code  transaction_id  tran_date  \
# 0           268408 1970-02-01      M        4.0     87243835584 2014-01-13
# 1           275152 1970-01-16      M        4.0     73109425404 2011-03-25
# 2           275034 1970-01-18      F        4.0     64777271023 2011-05-23
# 3           270829 1970-01-22      F        8.0     87174343938 2013-09-12
# 4           267657 1970-01-29      F        7.0     76242744953 2013-05-23
# ...            ...        ...    ...        ...             ...        ...
# 57161       272141 1992-02-12      F       10.0     79059585885 2012-10-25
# 57162       269719 1992-04-12      F        8.0     70553332101 2013-11-23
# 57163       275051 1992-04-12      M        5.0     77933614379 2013-05-18
# 57164       270695 1992-05-12      F        6.0      2300510157 2012-11-20
# 57165       270476 1992-12-25      F        3.0     85475160771 2011-09-08
#
# ...

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57166 entries, 0 to 57165
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       57166 non-null  int64
#  1   DOB               57166 non-null  datetime64[ns]
#  2   Gender            57144 non-null  object
#  3   city_code         57151 non-null  float64
#  4   transaction_id    57166 non-null  int64
#  5   tran_date         57166 non-null  datetime64[ns]
#  6   prod_subcat_code  57166 non-null  int64
#  7   prod_cat_code_x   57166 non-null  int64
#  8   Qty               57166 non-null  int64
#  9   Rate              57166 non-null  int64
#  10  Tax               57166 non-null  float64
#  11  total_amt         57166 non-null  float64
#  12  Store_type        57166 non-null  object
#  13  prod_cat_code_y   57166 non-null  int64
#  14  prod_cat          57166 non-null  object
#  15  prod_subcat       57166 non-null  object
# ...

# %%
2. Prepare a summary report for the merged data set.

# %%
Customer_Final.shape
# Out:
# (57166, 16)

# %%
Customer_Final.describe()
# Out:
#          customer_id     city_code  transaction_id  prod_subcat_code  \
# count   57166.000000  57151.000000    5.716600e+04      57166.000000
# mean   271015.375101      5.496457    5.017556e+10          5.613949
# std      2426.954106      2.865186    2.896442e+10          3.701183
# min    266783.000000      1.000000    3.268991e+06          1.000000
# 25%    268931.000000      3.000000    2.527880e+10          3.000000
# 50%    270982.000000      5.000000    5.019132e+10          4.000000
# 75%    273096.000000      8.000000    7.551116e+10         10.000000
# max    275265.000000     10.000000    9.998755e+10         12.000000
#
#        prod_cat_code_x           Qty          Rate           Tax  \
# count     57166.000000  57166.000000  57166.000000  57166.000000
# mean          3.462425      2.429766    635.022653    248.967409
# std           1.710811      2.273219    623.390431    187.344788
# min           1.000000     -5.000000  -1499.000000      7.350000
# ...

# %%
a. Get the column names and their corresponding data types

# %%
Customer_Final.columns
# Out:
# Index(['customer_id', 'DOB', 'Gender', 'city_code', 'transaction_id',
#        'tran_date', 'prod_subcat_code', 'prod_cat_code_x', 'Qty', 'Rate',
#        'Tax', 'total_amt', 'Store_type', 'prod_cat_code_y', 'prod_cat',
#        'prod_subcat'],
#       dtype='object')

# %%
Customer_Final.dtypes
# Out:
# customer_id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# transaction_id               int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code_x              int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat_code_y              int64
# prod_cat                    object
# prod_subcat                 object
# dtype: object

# %%
b. Top/Bottom 10 observations

# %%
Customer_Final.head(10)
# Out:
#    customer_id        DOB Gender  city_code  transaction_id  tran_date  \
# 0       268408 1970-02-01      M        4.0     87243835584 2014-01-13
# 1       275152 1970-01-16      M        4.0     73109425404 2011-03-25
# 2       275034 1970-01-18      F        4.0     64777271023 2011-05-23
# 3       270829 1970-01-22      F        8.0     87174343938 2013-09-12
# 4       267657 1970-01-29      F        7.0     76242744953 2013-05-23
# 5       274630 1970-01-02      M        4.0     78357345891 2012-11-04
# 6       273541 1970-01-02      M        4.0     23916816961 2013-09-02
# 7       269008 1970-02-13      F        6.0     35560569829 2013-09-03
# 8       269008 1970-02-13      F        6.0     94033312891 2012-04-26
# 9       267199 1970-02-14    NaN        2.0     56749259881 2012-11-01
#
#    prod_subcat_code  prod_cat_code_x  Qty  Rate      Tax  total_amt  \
# 0                 7                5    5   187   98.175   1033.175
# ...

# %%
Customer_Final.tail(10)
# Out:
#        customer_id        DOB Gender  city_code  transaction_id  tran_date  \
# 57156       273899 1992-07-10      F        5.0     28966519600 2011-12-31
# 57157       269241 1992-09-10      F        4.0     99372261440 2013-06-10
# 57158       270484 1992-10-14      F        1.0     49410470654 2013-11-13
# 57159       266825 1992-11-21      F        8.0      8969181661 2013-12-27
# 57160       267094 1992-11-24      M        9.0     12905992307 2014-01-26
# 57161       272141 1992-02-12      F       10.0     79059585885 2012-10-25
# 57162       269719 1992-04-12      F        8.0     70553332101 2013-11-23
# 57163       275051 1992-04-12      M        5.0     77933614379 2013-05-18
# 57164       270695 1992-05-12      F        6.0      2300510157 2012-11-20
# 57165       270476 1992-12-25      F        3.0     85475160771 2011-09-08
#
#        prod_subcat_code  prod_cat_code_x  Qty  Rate      Tax  total_amt  \
# ...

# %%
c. “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
Customer_Final.describe()
# Out:
#          customer_id     city_code  transaction_id  prod_subcat_code  \
# count   57166.000000  57151.000000    5.716600e+04      57166.000000
# mean   271015.375101      5.496457    5.017556e+10          5.613949
# std      2426.954106      2.865186    2.896442e+10          3.701183
# min    266783.000000      1.000000    3.268991e+06          1.000000
# 25%    268931.000000      3.000000    2.527880e+10          3.000000
# 50%    270982.000000      5.000000    5.019132e+10          4.000000
# 75%    273096.000000      8.000000    7.551116e+10         10.000000
# max    275265.000000     10.000000    9.998755e+10         12.000000
#
#        prod_cat_code_x           Qty          Rate           Tax  \
# count     57166.000000  57166.000000  57166.000000  57166.000000
# mean          3.462425      2.429766    635.022653    248.967409
# std           1.710811      2.273219    623.390431    187.344788
# min           1.000000     -5.000000  -1499.000000      7.350000
# ...

# %%
d. Frequency tables for all the categorical variables

# %%
frq=Customer_Final[['Gender','Store_type','prod_cat','prod_subcat',]]

# %%
frq.describe()
# Out:
#        Gender Store_type prod_cat prod_subcat
# count   57144      57166    57166       57166
# unique      2          4        6          18
# top         M     e-Shop    Books       Women
# freq    29191      23087    12179       10019

# %%
Customer_Final.loc[:,Customer_Final.dtypes=="object"].describe()
# Out:
#        Gender Store_type prod_cat prod_subcat
# count   57144      57166    57166       57166
# unique      2          4        6          18
# top         M     e-Shop    Books       Women
# freq    29191      23087    12179       10019

# %%
Customer_Final.describe(include='object')
# Out:
#        Gender Store_type prod_cat prod_subcat
# count   57144      57166    57166       57166
# unique      2          4        6          18
# top         M     e-Shop    Books       Women
# freq    29191      23087    12179       10019

# %%
db=Customer_Final['DOB']

# %%
db.value_counts()
# Out:
# 1982-09-17    79
# 1988-12-27    75
# 1974-02-25    73
# 1972-03-20    68
# 1988-07-21    64
#               ..
# 1988-01-27     1
# 1989-09-14     1
# 1990-09-07     1
# 1991-01-01     1
# 1989-06-02     1
# Name: DOB, Length: 3987, dtype: int64

# %%
db.describe()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_23968/4020874539.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   db.describe()
# count                   57166
# unique                   3987
# top       1982-09-17 00:00:00
# freq                       79
# first     1970-01-02 00:00:00
# last      1992-12-29 00:00:00
# Name: DOB, dtype: object

# %%
gen=Customer_Final['Gender']

# %%
gen.value_counts()
# Out:
# M    29191
# F    27953
# Name: Gender, dtype: int64

# %%
gen.describe()
# Out:
# count     57144
# unique        2
# top           M
# freq      29191
# Name: Gender, dtype: object

# %%
td=Customer_Final['tran_date']

# %%
td.value_counts()
# Out:
# 2012-11-25    90
# 2011-07-13    89
# 2011-07-10    86
# 2011-10-23    85
# 2013-04-01    85
#               ..
# 2014-02-28     3
# 2014-02-24     3
# 2014-02-23     2
# 2014-02-21     1
# 2014-02-27     1
# Name: tran_date, Length: 1129, dtype: int64

# %%
td.describe()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_23968/1937149455.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   td.describe()
# count                   57166
# unique                   1129
# top       2012-11-25 00:00:00
# freq                       90
# first     2011-01-02 00:00:00
# last      2014-12-02 00:00:00
# Name: tran_date, dtype: object

# %%
st=Customer_Final['Store_type']

# %%
st.value_counts()
# Out:
# e-Shop            23087
# MBR               11644
# Flagship store    11324
# TeleShop          11111
# Name: Store_type, dtype: int64

# %%
st.describe()
# Out:
# count      57166
# unique         4
# top       e-Shop
# freq       23087
# Name: Store_type, dtype: object

# %%
pc=Customer_Final['prod_cat']

# %%
pc.value_counts()
# Out:
# Books               12179
# Clothing            10019
# Footwear            10019
# Electronics          9910
# Home and kitchen     8087
# Bags                 6952
# Name: prod_cat, dtype: int64

# %%
pc.describe()
# Out:
# count     57166
# unique        6
# top       Books
# freq      12179
# Name: prod_cat, dtype: object

# %%
ps=Customer_Final['prod_subcat']

# %%
ps.value_counts()
# Out:
# Women                  10019
# Mens                    9902
# Kids                    7069
# Mobiles                 4002
# Comics                  3067
# Audio and video         2993
# Non-Fiction             2993
# Kitchen                 2993
# Children                2058
# Bath                    2058
# Academic                2029
# Tools                   2029
# Fiction                 1043
# Furnishing              1007
# DIY                      989
# Cameras                  985
# Personal Appliances      972
# Computers                958
# Name: prod_subcat, dtype: int64

# %%
ps.describe()
# Out:
# count     57166
# unique       18
# top       Women
# freq      10019
# Name: prod_subcat, dtype: object

# %%
3. Generate histograms for all continuous variables and frequency bars for categorical variables.

# %%
Customer_Final[['customer_id','city_code','transaction_id','prod_subcat_code','prod_cat_code_x','Qty','Rate','Tax','total_amt','prod_cat_code_y']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'customer_id'}>,
#         <AxesSubplot:title={'center':'city_code'}>,
#         <AxesSubplot:title={'center':'transaction_id'}>],
#        [<AxesSubplot:title={'center':'prod_subcat_code'}>,
#         <AxesSubplot:title={'center':'prod_cat_code_x'}>,
#         <AxesSubplot:title={'center':'Qty'}>],
#        [<AxesSubplot:title={'center':'Rate'}>,
#         <AxesSubplot:title={'center':'Tax'}>,
#         <AxesSubplot:title={'center':'total_amt'}>],
#        [<AxesSubplot:title={'center':'prod_cat_code_y'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
pd.crosstab(index=Customer_Final['Gender'], columns="count")
# Out:
# col_0   count
# Gender
# F       27953
# M       29191

# %%
pd.crosstab(index=Customer_Final['Store_type'], columns="count")
# Out:
# col_0           count
# Store_type
# Flagship store  11324
# MBR             11644
# TeleShop        11111
# e-Shop          23087

# %%
pd.crosstab(index=Customer_Final['prod_cat'], columns="count")
# Out:
# col_0             count
# prod_cat
# Bags               6952
# Books             12179
# Clothing          10019
# Electronics        9910
# Footwear          10019
# Home and kitchen   8087

# %%
pd.crosstab(index=Customer_Final['prod_subcat'], columns="count")
# Out:
# col_0                count
# prod_subcat
# Academic              2029
# Audio and video       2993
# Bath                  2058
# Cameras                985
# Children              2058
# Comics                3067
# Computers              958
# DIY                    989
# Fiction               1043
# Furnishing            1007
# Kids                  7069
# Kitchen               2993
# Mens                  9902
# Mobiles               4002
# Non-Fiction           2993
# Personal Appliances    972
# Tools                 2029
# Women                10019

# %%
4. Calculate the following information using the merged dataset :
a. Time period of the available transaction data

# %%
start=Customer_Final["tran_date"].min()

# %%
end=Customer_Final["tran_date"].max()

# %%
time_period = end-start

# %%
time_period
# Out:
# Timedelta('1430 days 00:00:00')

# %%
b. Count of transactions where the total amount of transaction was negative

# %%
(Customer_Final['total_amt'] < 0).sum().sum()
# Out:
# 5430

# %%
5. Analyze which product categories are more popular among females vs male customers.

# %%
Customer_Final.tail()
# Out:
#        customer_id        DOB Gender  city_code  transaction_id  tran_date  \
# 57161       272141 1992-02-12      F       10.0     79059585885 2012-10-25
# 57162       269719 1992-04-12      F        8.0     70553332101 2013-11-23
# 57163       275051 1992-04-12      M        5.0     77933614379 2013-05-18
# 57164       270695 1992-05-12      F        6.0      2300510157 2012-11-20
# 57165       270476 1992-12-25      F        3.0     85475160771 2011-09-08
#
#        prod_subcat_code  prod_cat_code_x  Qty  Rate      Tax  total_amt  \
# 57161                 5                3    2  1354  284.340   2992.340
# 57162                 5                3    2   623  130.830   1376.830
# 57163                 5                3    5  1095  574.875   6049.875
# 57164                 5                3    3   906  285.390   3003.390
# 57165                 5                3    5  1354  710.850   7480.850
#
#            Store_type  prod_cat_code_y     prod_cat prod_subcat
# ...

# %%
Customer_Final.groupby(['Gender','prod_cat'])[['Qty']].sum()
# Out:
#                            Qty
# Gender prod_cat
# F      Bags               8120
#        Books             14626
#        Clothing          11817
#        Electronics       11811
#        Footwear          11817
#        Home and kitchen   9752
# M      Bags               8752
#        Books             14885
#        Clothing          12370
#        Electronics       12626
#        Footwear          12370
#        Home and kitchen   9906

# %%
6. Which City code has the maximum customers and what was the percentage of customers from
that city?

# %%
max_cust=Customer_Final.groupby('city_code')['customer_id'].count().sort_values(ascending=False)

# %%
max_cust
# Out:
# city_code
# 4.0     5961
# 5.0     5941
# 3.0     5886
# 10.0    5800
# 8.0     5771
# 7.0     5761
# 2.0     5616
# 1.0     5582
# 9.0     5538
# 6.0     5295
# Name: customer_id, dtype: int64

# %%
plt.figure(figsize=(8,5))
Customer_Final.plot(kind="bar")
plt.xlabel("City Code")
plt.ylabel("No. of customers")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23968/3885533723.py in <module>
# ----> 1 plt.figure(figsize=(8,5))
#       2 Customer_Final.plot(kind="bar")
#       3 plt.xlabel("City Code")
#       4 plt.ylabel("No. of customers")
#       5 plt.show()
#
# TypeError: 'module' object is not callable

# %%
percent=(max_cust[4.0]/max_cust.sum())*100

# %%
percent
# Out:
# 10.430263687424542

# %%
7. Which store type sells the maximum products by value and by quantity?

# %%
Customer_Final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_23968/3468065753.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Customer_Final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)
#                   Qty      Rate
# Store_type
# e-Shop          56372  14749891
# MBR             27869   7363725
# Flagship store  27600   7237152
# TeleShop        27059   6950937

# %%
8. What was the total amount earned from the "Electronics" and "Clothing" categories from
Flagship Stores?

# %%
cat = round(Customer_Final.pivot_table(index = "prod_cat",columns="Store_type", values="total_amt", aggfunc='sum'),2)

# %%
cat
# Out:
# Store_type        Flagship store         MBR    TeleShop       e-Shop
# prod_cat
# Bags                  2934702.10  2897764.16  2802855.70   6012958.06
# Books                 5042076.32  5124308.22  4941219.66  10391589.06
# Clothing              4177586.20  4114928.28  4066630.94   8586025.70
# Electronics           4349256.80  4252884.22  3879603.06   8664738.16
# Footwear              4177586.20  4114928.28  4066630.94   8586025.70
# Home and kitchen      3391451.64  3513354.13  3223408.76   6855252.04

# %%
cat1=Customer_Final.groupby(['prod_cat','Store_type'])[['total_amt',]].sum()

# %%
cat1
# Out:
#                                     total_amt
# prod_cat         Store_type
# Bags             Flagship store  2.934702e+06
#                  MBR             2.897764e+06
#                  TeleShop        2.802856e+06
#                  e-Shop          6.012958e+06
# Books            Flagship store  5.042076e+06
#                  MBR             5.124308e+06
#                  TeleShop        4.941220e+06
#                  e-Shop          1.039159e+07
# Clothing         Flagship store  4.177586e+06
#                  MBR             4.114928e+06
#                  TeleShop        4.066631e+06
#                  e-Shop          8.586026e+06
# Electronics      Flagship store  4.349257e+06
#                  MBR             4.252884e+06
#                  TeleShop        3.879603e+06
#                  e-Shop          8.664738e+06
# Footwear         Flagship store  4.177586e+06
#                  MBR             4.114928e+06
#                  TeleShop        4.066631e+06
# ...

# %%
cat.loc[['Clothing','Electronics'],'Flagship store'].sum()
# Out:
# 8526843.0

# %%
9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
gender=round(Customer_Final.pivot_table(index ='prod_cat' ,columns='Gender', values='total_amt', aggfunc='sum'),2)

# %%
gender
# Out:
# Gender                      F            M
# prod_cat
# Bags               7141184.05   7504546.72
# Books             12500565.54  12980551.02
# Clothing          10309103.02  10633211.68
# Electronics       10193068.08  10947130.02
# Footwear          10309103.02  10633211.68
# Home and kitchen   8344074.90   8626528.36

# %%
gender.loc['Electronics','M']
# Out:
# 10947130.02

# %%
10. How many customers have more than 10 unique transactions, after removing all transactions
which have any negative amounts?

# %%
positive = Customer_Final.loc[Customer_Final["total_amt"]>0]

# %%
positive
# Out:
#        customer_id        DOB Gender  city_code  transaction_id  tran_date  \
# 0           268408 1970-02-01      M        4.0     87243835584 2014-01-13
# 1           275152 1970-01-16      M        4.0     73109425404 2011-03-25
# 2           275034 1970-01-18      F        4.0     64777271023 2011-05-23
# 3           270829 1970-01-22      F        8.0     87174343938 2013-09-12
# 4           267657 1970-01-29      F        7.0     76242744953 2013-05-23
# ...            ...        ...    ...        ...             ...        ...
# 57161       272141 1992-02-12      F       10.0     79059585885 2012-10-25
# 57162       269719 1992-04-12      F        8.0     70553332101 2013-11-23
# 57163       275051 1992-04-12      M        5.0     77933614379 2013-05-18
# 57164       270695 1992-05-12      F        6.0      2300510157 2012-11-20
# 57165       270476 1992-12-25      F        3.0     85475160771 2011-09-08
#
# ...

# %%
unique = positive.groupby(['customer_id','transaction_id'])['transaction_id'].count()

# %%
unique
# Out:
# customer_id  transaction_id
# 266783       8410316370        4
#              16999552161       3
#              25890929042       3
#              98477711300       4
# 266784       26928161256       1
#                               ..
# 275264       81382444243       2
#              94712826085       3
# 275265       7214136016        3
#              24113900219       1
#              38961184788       2
# Name: transaction_id, Length: 20876, dtype: int64

# %%
cnt=unique.groupby('customer_id')['transaction_id'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23968/2437265092.py in <module>
# ----> 1 cnt=unique.groupby('customer_id')['transaction_id'].count()
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: transaction_id'

# %%
cnt.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23968/444226943.py in <module>
# ----> 1 cnt.head()
#
# NameError: name 'cnt' is not defined
